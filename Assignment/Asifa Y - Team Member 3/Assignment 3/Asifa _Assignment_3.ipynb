# %% [markdown]
# ## Exercises
#
# Answer the questions or complete the tasks outlined in bold below, use the specific method described if applicable.

# %% [markdown]
# ** What is 7 to the power of 4?**

# %%
print(pow(7,4))
# Out:
# 2401

# %% [markdown]
# ** Split this string:**
#
#     s = "Hi there Sam!"
#
# **into a list. **

# %%
s="Hi there Sam!"
list=s.split(" ")
print(list)
# Out:
# ['Hi', 'there', 'Sam!']

# %%
s="Hi there dad!"
list=s.split(" ")
print(list)
# Out:
# ['Hi', 'there', 'dad!']

# %% [markdown]
# ** Given the variables:**
#
#     planet = "Earth"
#     diameter = 12742
#
# ** Use .format() to print the following string: **
#
#     The diameter of Earth is 12742 kilometers.

# %%
planet="Earth"
diameter=12742
print("The diameter of {} is {} kilometers".format(planet,diameter))
# Out:
# The diameter of Earth is 12742 kilometers

# %%
lst=[1,2,[3,4],[5,[100,200,['hello']],23,11],1,7]
wrd=lst[3][1][2]
print(wrd)
# Out:
# ['hello']

# %% [markdown]
# ** Given this nested list, use indexing to grab the word "hello" **

# %%
lst = [1,2,[3,4],[5,[100,200,['hello']],23,11],1,7]
wrd=lst[3][1][2]
print(wrd)
# Out:
# ['hello']

# %%
# Out:
# 'hello'

# %% [markdown]
# ** Given this nest dictionary grab the word "hello". Be prepared, this will be annoying/tricky **

# %%
d = {'k1':[1,2,3,{'tricky':['oh','man','inception',{'target':[1,2,3,'hello']}]}]}

# %%
d={'k1':[1,2,3,{'tricky':['oh','man','inception',{'target':[1,2,3,'hello']}]}]}
print(d['k1'][3]['tricky'][3]['target'][3])
# Out:
# hello

# %% [markdown]
# ** What is the main difference between a tuple and a list? **

# %%
#LIST:
   #List is mutable
   #List consumes more memory
   #List are denoted by square brackets
   #Example: list=['asifa',3]

#TUPLE:
   #Tuple is immutable
   #Tuple consumes less memory
   #Tuples are denoted by parenthesis
   #Example: tuple=('asifa',3)

# %% [markdown]
# ** Create a function that grabs the email website domain from a string in the form: **
#
#     user@domain.com
#
# **So for example, passing "user@domain.com" would return: domain.com**

# %%
def domain(email):
  print(email.split('@'[-1]))
domain("user@domain.com")
# Out:
# ['user', 'domain.com']

# %%
# Out:
# 'domain.com'

# %% [markdown]
# ** Create a basic function that returns True if the word 'dog' is contained in the input string. Don't worry about edge cases like a punctuation being attached to the word dog, but do account for capitalization. **

# %%
def FindWord(string):
  str=string.lower()
  if "dog" in string:
    print("True")
  else:
    print("False")

FindWord('My dog is tommy')
FindWord('My name is asifa')
# Out:
# True
# False

# %%
# Out:
# True

# %% [markdown]
# ** Create a function that counts the number of times the word "dog" occurs in a string. Again ignore edge cases. **

# %%
def countWord(str):
  count=0
  for word in str.lower().split():
    if word=='dog':
      count=count+1

  print(count)
countWord('This dog runs faster than the other dog')
# Out:
# 2

# %%
# Out:
# 2

# %% [markdown]
# ### Problem
# **You are driving a little too fast, and a police officer stops you. Write a function
#   to return one of 3 possible results: "No ticket", "Small ticket", or "Big Ticket".
#   If your speed is 60 or less, the result is "No Ticket". If speed is between 61
#   and 80 inclusive, the result is "Small Ticket". If speed is 81 or more, the result is "Big    Ticket". Unless it is your birthday (encoded as a boolean value in the parameters of the function) -- on your birthday, your speed can be 5 higher in all
#   cases. **

# %%
def caught_speeding(speed, is_birthday):
    
    if is_birthday:
        speeding = speed - 5
    else:
        speeding = speed
    
    if speeding > 80:
        return 'Big Ticket'
    elif speeding > 60:
        return 'Small Ticket'
    else:
        return 'No Ticket'

# %%
caught_speeding(83,True)
# Out:
# 'Small Ticket'

# %%
caught_speeding(85,False)
# Out:
# 'Big Ticket'

# %% [markdown]
# Create an employee list with basic salary values(at least 5 values for 5 employees)  and using a for loop retreive each employee salary and calculate total salary expenditure.

# %%
employee=[['Asifa',50000],['Prathiksha',45000],['Aruna',30000],['Deksha',55000]]
total_salary=0
length=len(employee)
for name,salary in employee:
  total_salary+=salary
average_salary=total_salary/length
print(average_salary)
salary_expenditure=average_salary * length
print(salary_expenditure)
# Out:
# 45000.0
# 180000.0

# %% [markdown]
# Create two dictionaries in Python:
#
# First one to contain fields as Empid,  Empname,  Basicpay
#
# Second dictionary to contain fields as DeptName,  DeptId.
#
# Combine both dictionaries.

# %%
def combineDictionary(dict1,dict2):
  for i in dict2.keys():
    dict1[i]=dict2[i]
  return dict1
dict1={'Empid':300,'Empname':'Asifa','BasicPay':30000}
dict2={'DeptName':'Application Developer','Deptid':6}
finaldict=combineDictionary(dict1,dict2)
print(finaldict)
# Out:
# {'Empid': 300, 'Empname': 'Asifa', 'BasicPay': 30000, 'DeptName': 'Application Developer', 'Deptid': 6}
